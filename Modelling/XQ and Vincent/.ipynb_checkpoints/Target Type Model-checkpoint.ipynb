# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import seaborn as sns

# Trying to predict: targtype1_txt
# With inputs: country_txt, gname, attacktype1_txt

# %%
# Data Preprocessing - Removing NA and NaN Values

df = pd.read_csv('terrorism_new.csv')
df = df.loc[:,['gname', 'country_txt', 'attacktype1_txt', 'targtype1_txt']]
# df = df.loc[:,['gname', 'region_txt', 'attacktype1_txt', 'targtype1_txt']]

df = df.rename(columns={'gname' : 'group_name', 'country_txt' : 'country', 'attacktype1_txt' : 'attack_type', 'targtype1_txt' : 'target_type'})
# df = df.rename(columns={'gname' : 'group_name', 'region_txt' : 'region', 'attacktype1_txt' : 'attack_type', 'targtype1_txt' : 'target_type'})

df['group_name'] = df.loc[df['group_name'] != 'Unknown']['group_name']
df['attack_type'] = df.loc[df['attack_type'] != 'Unknown']['attack_type']
df['target_type'] = df.loc[df['target_type'] != 'Unknown']['target_type']
df['country'] = df.loc[df['country'] != 'Unknown']['country']
# df['region'] = df.loc[df['region'] != 'Unknown']['region']

df = df.dropna()
df


# df.to_csv('targettype_prediction.csv')
# Out:
# /Users/vincent/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (4,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                group_name  \
# 0                                                  MANO-D
# 1                      23rd of September Communist League
# 5                                      Black Nationalists
# 6                                     Tupamaros (Uruguay)
# 8                                         New Year's Gang
# 9                                         New Year's Gang
# 10                        Weather Underground, Weathermen
# 11                                    Left-Wing Militants
# 13                                    Left-Wing Militants
# 14                          Armed Commandos of Liberation
# 15                                              Commune 1
# 17                                     Black Nationalists
# 18                                               Strikers
# 19                                     Black Nationalists
# 20                                     Black Nationalists
# 21                                    Tupamaros (Uruguay)
# 22                                     Black Nationalists
# 23                                       Student Radicals
# 24                        White supremacists/nationalists
# 27      Armed Forces of National Liberation- Venezuela...
# 28                                               Strikers
# 29                        White supremacists/nationalists
# 30                                     Black Nationalists
# 31                                     Black Nationalists
# 32                                     Black Nationalists
# 33                                    Left-Wing Militants
# 35                        White supremacists/nationalists
# 37                                               Strikers
# 38                                       Student Radicals
# 41                                    Left-Wing Militants
# ...                                                   ...
# 191407                    Houthi extremists (Ansar Allah)
# 191408                                            Taliban
# 191409     Communist Party of India - Maoist (CPI-Maoist)
# 191410     Communist Party of India - Maoist (CPI-Maoist)
# 191411     Communist Party of India - Maoist (CPI-Maoist)
# 191412     Communist Party of India - Maoist (CPI-Maoist)
# 191417                                            Taliban
# 191418                         Anti-Government extremists
# 191420                                         Boko Haram
# 191421        Islamic State of Iraq and the Levant (ISIL)
# 191426                              Lashkar-e-Taiba (LeT)
# 191428                             Jaish-e-Mohammad (JeM)
# 191430                    Mujahidin Indonesia Timur (MIT)
# 191431                    Houthi extremists (Ansar Allah)
# 191432                    Houthi extremists (Ansar Allah)
# 191433                                  Fulani extremists
# 191434                                  Fulani extremists
# 191438                                            Taliban
# 191440                                        Maute Group
# 191442        Islamic State of Iraq and the Levant (ISIL)
# 191443                                            Taliban
# 191445                         Jihadi-inspired extremists
# 191446                                            Taliban
# 191447                                            Taliban
# 191451                                        Separatists
# 191453                    Mujahidin Indonesia Timur (MIT)
# 191457  Popular Front for the Renaissance of the Centr...
# 191459                                            Taliban
# 191460                                            Taliban
# 191463                              Dissident Republicans
#
#                              region                     attack_type  \
# 0       Central America & Caribbean                   Assassination
# 1                     North America     Hostage Taking (Kidnapping)
# 5                     North America                   Armed Assault
# 6                     South America                   Assassination
# 8                     North America  Facility/Infrastructure Attack
# 9                     North America  Facility/Infrastructure Attack
# 10                    North America               Bombing/Explosion
# 11                    North America  Facility/Infrastructure Attack
# 13                    North America  Facility/Infrastructure Attack
# 14                    North America  Facility/Infrastructure Attack
# 15                   Eastern Europe               Bombing/Explosion
# 17                    North America               Bombing/Explosion
# 18                    North America               Bombing/Explosion
# 19                    North America  Facility/Infrastructure Attack
# 20                    North America  Facility/Infrastructure Attack
# 21                    South America                   Armed Assault
# 22                    North America               Bombing/Explosion
# 23                    North America               Bombing/Explosion
# 24                    North America  Facility/Infrastructure Attack
# 27                    South America     Hostage Taking (Kidnapping)
# 28                    North America               Bombing/Explosion
# 29                    North America  Facility/Infrastructure Attack
# 30                    North America                   Armed Assault
# 31                    North America               Bombing/Explosion
# 32                    North America                   Armed Assault
# 33                    North America  Facility/Infrastructure Attack
# 35                    North America               Bombing/Explosion
# 37                    North America               Bombing/Explosion
# 38                    North America  Facility/Infrastructure Attack
# 41                    North America  Facility/Infrastructure Attack
# ...                             ...                             ...
# 191407   Middle East & North Africa               Bombing/Explosion
# 191408                   South Asia               Bombing/Explosion
# 191409                   South Asia               Bombing/Explosion
# 191410                   South Asia  Facility/Infrastructure Attack
# 191411                   South Asia               Bombing/Explosion
# 191412                   South Asia  Facility/Infrastructure Attack
# 191417                   South Asia     Hostage Taking (Kidnapping)
# 191418               Southeast Asia                   Armed Assault
# 191420           Sub-Saharan Africa                   Armed Assault
# 191421   Middle East & North Africa                   Armed Assault
# 191426                   South Asia  Facility/Infrastructure Attack
# 191428                   South Asia                   Armed Assault
# 191430               Southeast Asia     Hostage Taking (Kidnapping)
# 191431   Middle East & North Africa     Hostage Taking (Kidnapping)
# 191432   Middle East & North Africa  Facility/Infrastructure Attack
# 191433           Sub-Saharan Africa                   Armed Assault
# 191434           Sub-Saharan Africa                   Armed Assault
# 191438                   South Asia                   Armed Assault
# 191440               Southeast Asia               Bombing/Explosion
# 191442   Middle East & North Africa               Bombing/Explosion
# 191443                   South Asia                   Armed Assault
# 191445               Western Europe                   Armed Assault
# 191446                   South Asia                   Armed Assault
# 191447                   South Asia                   Armed Assault
# 191451           Sub-Saharan Africa                   Assassination
# 191453               Southeast Asia                   Armed Assault
# 191457           Sub-Saharan Africa                   Armed Assault
# 191459                   South Asia  Facility/Infrastructure Attack
# 191460                   South Asia  Facility/Infrastructure Attack
# 191463               Western Europe  Facility/Infrastructure Attack
#
#                            target_type
# 0          Private Citizens & Property
# 1              Government (Diplomatic)
# 5                               Police
# 6                               Police
# 8                             Military
# 9                 Government (General)
# 10                            Military
# 11                            Military
# 13                Government (General)
# 14                            Business
# 15                Government (General)
# 17             Educational Institution
# 18                            Business
# 19                            Business
# 20                              Police
# 21             Educational Institution
# 22             Educational Institution
# 23                            Military
# 24             Violent Political Party
# 27                            Business
# 28         Private Citizens & Property
# 29         Private Citizens & Property
# 30                              Police
# 31                Government (General)
# 32                              Police
# 33                Government (General)
# 35      Religious Figures/Institutions
# 37                            Business
# 38                            Military
# 41                Government (General)
# ...                                ...
# 191407     Private Citizens & Property
# 191408     Private Citizens & Property
# 191409            Government (General)
# 191410     Private Citizens & Property
# 191411     Private Citizens & Property
# 191412     Private Citizens & Property
# 191417     Private Citizens & Property
# 191418     Private Citizens & Property
# 191420     Private Citizens & Property
# 191421                        Military
# 191426            Government (General)
# 191428                        Military
# 191430                        Business
# 191431                             NGO
# 191432                             NGO
# 191433     Private Citizens & Property
# 191434     Private Citizens & Property
# 191438                          Police
# 191440                        Business
# 191442                        Military
# 191443                          Police
# 191445                  Transportation
# 191446                       Utilities
# 191447                       Utilities
# 191451            Government (General)
# 191453                          Police
# 191457     Private Citizens & Property
# 191459                          Police
# 191460                        Military
# 191463     Private Citizens & Property
#
# [96484 rows x 4 columns]

# %%
# rng = np.random.RandomState(1)
# X = rng.randint(5, size=(6, 100))
# y = np.array([1, 2, 3, 4, 5, 6])
# from sklearn.naive_bayes import MultinomialNB
# clf = MultinomialNB()
# clf.fit(X, y)
# MultinomialNB()

# Z = rng.randint(5, size=(1, 100))

# print(clf.predict(Z))

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import numpy as np


labeledDF = df.apply(LabelEncoder().fit_transform) 

# print(labeledDF)
classes = np.array(labeledDF['target_type'])
print(classes)
newDF = labeledDF.iloc[:,0:3]

attributes = np.array(newDF)
print(attributes)

X_train, X_test, y_train, y_test = train_test_split(attributes, classes, test_size=0.33, random_state=42)

print('Training Features Shape:', X_train.shape)
print('Training Labels Shape:', y_train.shape)
print('Testing Features Shape:', X_test.shape)
print('Testing Labels Shape:', y_test.shape)

from sklearn.naive_bayes import CategoricalNB
clf = CategoricalNB()
print(clf)
clf.fit(X_train, y_train)

y_pred_test = clf.predict(X_test)

print(y_pred_test)
print(y_test)

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# View accuracy score
print('accuracy: {}'.format(accuracy_score(y_test, y_pred_test)))
matrix = confusion_matrix(y_test, y_pred_test)

# print(matrix)
# Out:
# [13  5 12 ... 12  9 13]
# [[1884    1    1]
#  [  13    6    6]
#  [ 679    6    0]
#  ...
#  [3102    8    3]
#  [3102    8    3]
#  [1019   11    3]]
# Training Features Shape: (64644, 3)
# Training Labels Shape: (64644,)
# Testing Features Shape: (31840, 3)
# Testing Labels Shape: (31840,)
# CategoricalNB()
# [19 13  6 ...  2  2  2]
# [13 13  2 ... 12  9 14]
# accuracy: 0.40065954773869344
