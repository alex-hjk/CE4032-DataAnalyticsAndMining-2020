# %%
import pandas as pd
import matplotlib
import plotly
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('terrorism_new.csv')
# df = df.loc[:,['motive', 'crit1', 'crit2', 'crit3', 'attacktype1', 'attacktype1_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt', ]]
df['attacktype1_txt'] = df['attacktype1_txt'].astype('category')
df['targtype1_txt'] = df['targtype1_txt'].astype('category')
df['casualitiestotal']=df['nkill']+df['nwound']
df['nkillvic'] = df['nkill'] - df['nkillter']
df['nwoundvic'] = df['nwound'] - df['nwoundte']
df.head()
# Out:
# /Users/xiaoqi.lim/Desktop/FYP/data-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (4,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... scite3 dbsource INT_LOG  INT_IDEO  \
# 0  Dominican Republic       2  ...    NaN     PGIS       0         0
# ...

# %%
print(df.loc[df['INT_LOG'] != -9]['INT_LOG'].count() / len(df))
print(df.loc[df['INT_IDEO'] != -9]['INT_IDEO'].count() / len(df))
print(df.loc[df['INT_MISC'] != -9]['INT_MISC'].count() / len(df))
# Out:
# 0.4931893201855179
# 0.49249989554172063
# 0.9974564408975055

# %%
pd.crosstab(df.region_txt,df.INT_LOG).plot.barh(stacked=True,width=1,color=sns.color_palette('RdYlGn',9))
fig=plt.gcf()
fig.set_size_inches(12,8)
plt.title("INT_LOG across regions")
plt.show()

# %%
pd.crosstab(df.region_txt,df.INT_IDEO).plot.barh(stacked=True,width=1,color=sns.color_palette('RdYlGn',9))
fig=plt.gcf()
fig.set_size_inches(12,8)
plt.title("INT_IDEO across regions")
plt.show()

# %%
pd.crosstab(df.region_txt,df.INT_MISC).plot.barh(stacked=True,width=1,color=sns.color_palette('RdYlGn',9))
fig=plt.gcf()
fig.set_size_inches(12,8)
plt.title("INT_MISC across regions")
plt.show()

# %%
pd.crosstab(df.region_txt,df.INT_ANY).plot.barh(stacked=True,width=1,color=sns.color_palette('RdYlGn',9))
fig=plt.gcf()
fig.set_size_inches(12,8)
plt.title("INT_ANY across regions")
plt.show()

# %%
pd.crosstab(df.attacktype1_txt,df.INT_LOG).plot.barh(stacked=True,width=1,color=sns.color_palette('RdYlGn',9))
fig=plt.gcf()
fig.set_size_inches(12,8)
plt.title("INT_LOG across attack type")
plt.show()

# %%
pd.crosstab(df.attacktype1_txt,df.INT_IDEO).plot.barh(stacked=True,width=1,color=sns.color_palette('RdYlGn',9))
fig=plt.gcf()
fig.set_size_inches(12,8)
plt.title("INT_LOG across attack type")
plt.show()

# %%
pd.crosstab(df.attacktype1_txt,df.INT_MISC).plot.barh(stacked=True,width=1,color=sns.color_palette('RdYlGn',9))
fig=plt.gcf()
fig.set_size_inches(12,8)
plt.title("INT_MISC across attack type")
plt.show()

# %%
pd.crosstab(df.attacktype1_txt,df.INT_ANY).plot.barh(stacked=True,width=1,color=sns.color_palette('RdYlGn',9))
fig=plt.gcf()
fig.set_size_inches(12,8)
plt.title("INT_ANY across attack type")
plt.show()

# %%
plt.subplots(figsize=(15,6))
sns.countplot('iyear',data=df,palette='RdYlGn_r',edgecolor=sns.color_palette('dark',7))
plt.xticks(rotation=90)
plt.title('Number Of Terrorist Activities Each Year')
plt.show()
# Out:
# /Users/xiaoqi.lim/Desktop/FYP/data-env/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.subplots(figsize=(15,6))
sns.countplot('region_txt',data=df ,palette='RdYlGn',edgecolor=sns.color_palette('dark',7),order=df['region_txt'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Number Of Terrorist Activities By Region')
plt.show()
# Out:
# /Users/xiaoqi.lim/Desktop/FYP/data-env/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
terror_region=pd.crosstab(df.iyear,df.region_txt)
terror_region.plot(color=sns.color_palette('Set2',12))
fig=plt.gcf()
fig.set_size_inches(18,6)
plt.show()

# %%
pd.crosstab(df.region_txt,df.attacktype1_txt).plot.barh(stacked=True,width=1,color=sns.color_palette('RdYlGn',9))
fig=plt.gcf()
fig.set_size_inches(12,8)
plt.title("Types of attack across regions")
plt.show()

# %%
pd.crosstab(df.region_txt,df.targtype1_txt).plot.bar(stacked=True,width=1,color=sns.color_palette('RdYlGn',9))
fig=plt.gcf()
fig.set_size_inches(12,8)
plt.title("Types of targets across regions")
plt.show()

# %%
pd.crosstab(df.attacktype1_txt,df.targtype1_txt).plot.bar(stacked=True,width=1,color=sns.color_palette('RdYlGn',9))
fig=plt.gcf()
fig.set_size_inches(12,8)
plt.title("Types of targets across attacks")
plt.show()

# %%
coun_terror=df['region_txt'].value_counts().to_frame()
coun_terror.columns=['Attacks']
coun_kill=df.groupby('region_txt')['nkillvic'].sum().to_frame()
coun_wound = df.groupby('region_txt')['nwoundvic'].sum().to_frame()
count_terror_kill = coun_terror.merge(coun_kill,left_index=True,right_index=True,how='left')
count_terror_kill.merge(coun_wound,left_index=True,right_index=True,how='left').plot.bar(width=0.9)

fig=plt.gcf()
fig.set_size_inches(18,6)
plt.title("Victim casualties across Regions")
plt.show()

# %%
coun_terror=df['attacktype1_txt'].value_counts().to_frame()
coun_terror.columns=['Attacks']
coun_kill=df.groupby('attacktype1_txt')['nkillvic'].sum().to_frame()
coun_wound = df.groupby('attacktype1_txt')['nwoundvic'].sum().to_frame()
count_terror_kill = coun_terror.merge(coun_kill,left_index=True,right_index=True,how='left')
count_terror_kill.merge(coun_wound,left_index=True,right_index=True,how='left').plot.bar(width=0.9)

fig=plt.gcf()
fig.set_size_inches(18,6)
plt.title("Victim casualties across Attacks")
plt.show()

# %%
coun_terror=df['region_txt'].value_counts().to_frame()
coun_terror.columns=['Attacks']
coun_kill=df.groupby('region_txt')['nkillus'].sum().to_frame()
coun_wound = df.groupby('region_txt')['nwoundus'].sum().to_frame()
count_terror_kill = coun_terror.merge(coun_kill,left_index=True,right_index=True,how='left')
count_terror_kill.merge(coun_wound,left_index=True,right_index=True,how='left').plot.bar(width=0.9)

fig=plt.gcf()
fig.set_size_inches(18,6)
plt.title("US Victim casualties across Attacks, tbh idk what i expected...")
plt.show()

# %%
coun_terror=df['attacktype1_txt'].value_counts().to_frame()
coun_terror.columns=['Attacks']
coun_kill=df.groupby('attacktype1_txt')['claimed'].sum().to_frame()
# coun_wound = df.groupby('region_txt')['attacktype1_txt'].count().to_frame()
# count_terror_kill = coun_terror.merge(coun_kill,left_index=True,right_index=True,how='left')
coun_terror.merge(coun_kill,left_index=True,right_index=True,how='left').plot.bar(width=0.9)

fig=plt.gcf()
fig.set_size_inches(18,6)
plt.title("Percentage of attacks that are claimed, sorted by type")
plt.show()

# %%
df_claim_valid = df.loc[df['claimmode_txt'].notna()]

pd.crosstab(df_claim_valid.region_txt,df_claim_valid.claimmode_txt).plot.bar(stacked=True,width=1,color=sns.color_palette('RdYlGn',9))
fig=plt.gcf()
fig.set_size_inches(12,8)
plt.title("Types of claim modes across regions")
plt.show()

# %%
pd.crosstab(df_claim_valid.attacktype1_txt,df_claim_valid.claimmode_txt).plot.bar(stacked=True,width=1,color=sns.color_palette('RdYlGn',9))
fig=plt.gcf()
fig.set_size_inches(12,8)
plt.title("Types of claim modes across regions")
plt.show()

# %%
what kind of attacks are most deadly (nkills / attacks), where these attacks take place, against who, for what reason?

# %%
# df_org = df = pd.read_csv('terrorism_new.csv')
# df_org.head()
# cols = list(df_org.columns)
# count = df_org.count()
# for x in range(len(count)):
#     print('{}: {}'.format(cols[x], count[x] / len(df_org) * 100))
# Out:
# /Users/xiaoqi.lim/Desktop/FYP/data-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (4,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
df_claim = df_org.loc[df_org['claimed'] == 1]

# %%
df_claim[['iyear', 'claimmode_txt', 'gname', 'motive']]
# Out:
#         iyear                  claimmode_txt  \
# 8        1970                         Letter
# 14       1970                        Unknown
# 50       1970                         Letter
# 51       1970                         Letter
# 52       1970                         Letter
# ...       ...                            ...
# 191421   2018  Posted to website, blog, etc.
# 191442   2018  Posted to website, blog, etc.
# 191445   2018                 Personal claim
# 191446   2018                 Personal claim
# 191447   2018                 Personal claim
#
#                                                    gname  \
# 8                                        New Year's Gang
# 14                         Armed Commandos of Liberation
# 50      Armed Revolutionary Independence Movement (MIRA)
# 51      Armed Revolutionary Independence Movement (MIRA)
# 52      Armed Revolutionary Independence Movement (MIRA)
# ...                                                  ...
# ...

# %%
df = pd.read_csv('terrorism_new.csv')
df = df.loc[:,['motive', 'crit1', 'crit2', 'crit3', 'attacktype1', 'attacktype1_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt', ]]
df['attacktype1_txt'] = df['attacktype1_txt'].astype('category')
df['targtype1_txt'] = df['targtype1_txt'].astype('category')
df.head()
# Out:
# /Users/xiaoqi.lim/Desktop/FYP/data-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (4,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   motive  crit1  crit2  crit3  attacktype1                 attacktype1_txt  \
# 0    NaN      1      1      1            1                   Assassination
# 1    NaN      1      1      1            6     Hostage Taking (Kidnapping)
# 2    NaN      1      1      1            1                   Assassination
# 3    NaN      1      1      1            3               Bombing/Explosion
# 4    NaN      1      1      1            7  Facility/Infrastructure Attack
#
#    attacktype2 attacktype2_txt  attacktype3 attacktype3_txt  targtype1  \
# 0          NaN             NaN          NaN             NaN         14
# ...

# %%
print(df.loc[df['crit1'] == 1]['crit1'].count() / len(df))
print(df.loc[df['crit2'] == 1]['crit2'].count() / len(df))
print(df.loc[df['crit3'] == 1]['crit3'].count() / len(df))
# Out:
# 0.9884103539046505
# 0.9931266452179
# 0.8728377136171813

# %%
df.loc[df['crit2'] == 0]
# Out:
#                                                    motive  crit1  crit2  \
# 753                                                   NaN      1      0
# 941     The Black Liberation Army stole money in order...      1      0
# 1211    The Black Liberation Army stole money in order...      1      0
# 1220                                                  NaN      1      0
# 1346                                                  NaN      1      0
# ...                                                   ...    ...    ...
# 190667                                                NaN      1      0
# 190668                                                NaN      1      0
# 190910  The specific motive is unknown; however, sourc...      1      0
# 191243                                                NaN      1      0
# 191454                                                NaN      1      0
#
#         crit3  attacktype1                      attacktype1_txt  attacktype2  \
# ...

# %%
fig, axes = plt.subplots(nrows=1, ncols = 3)
df_crit1 = df.loc[df['crit1'] == 1]
df_crit1['attacktype1_txt'].value_counts().plot(kind='bar', ax = axes[0])
df_crit2 = df.loc[df['crit2'] == 1]
df_crit2['attacktype1_txt'].value_counts().plot(kind='bar', ax = axes[1])
df_crit3 = df.loc[df['crit3'] == 1]
df_crit3['attacktype1_txt'].value_counts().plot(kind='bar', ax = axes[2])
# Out:
# <AxesSubplot:>

# %%
fig, axes = plt.subplots(nrows=1, ncols = 3)
df_crit1 = df.loc[df['crit1'] == 1]
df_crit1['targtype1_txt'].value_counts().plot(kind='bar', ax = axes[0])
df_crit2 = df.loc[df['crit2'] == 1]
df_crit2['targtype1_txt'].value_counts().plot(kind='bar', ax = axes[1])
df_crit3 = df.loc[df['crit3'] == 1]
df_crit3['targtype1_txt'].value_counts().plot(kind='bar', ax = axes[2])
# Out:
# <AxesSubplot:>

# %%
df.loc[:,['attacktype1_txt']].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='attacktype1_txt'>

# %%
df.loc[:,['targtype1_txt']].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='targtype1_txt'>
