# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib import cm
import seaborn as sns
import numpy as np
import math

plt.rcParams["figure.figsize"] = (40,6)




import warnings
warnings.filterwarnings('ignore')

# %%
__=pd.read_csv('../../terrorism_new.csv',encoding='ISO-8859-1')

# %%
terror=__
terror.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type','weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)
terror=terror[['Year','Month','Day','Country','Region','city','latitude','longitude','AttackType','Killed','Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]
terror['casualities']=terror['Killed']+terror['Wounded']
terror.head(3)
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
#
#             city   latitude   longitude                   AttackType  Killed  \
# 0  Santo Domingo  18.456792  -69.951164                Assassination     1.0
# 1    Mexico city  19.371887  -99.086624  Hostage Taking (Kidnapping)     0.0
# 2        Unknown  15.478598  120.599741                Assassination     1.0
#
#    Wounded                   Target Summary  \
# 0      0.0             Julio Guzman     NaN
# 1      0.0  Nadine Chaval, daughter     NaN
# 2      0.0                 Employee     NaN
#
#                                 Group                  Target_type  \
# 0                              MANO-D  Private Citizens & Property
# 1  23rd of September Communist League      Government (Diplomatic)
# 2                             Unknown          Journalists & Media
#
#   Weapon_type Motive  casualities
# 0     Unknown    NaN          1.0
# 1     Unknown    NaN          0.0
# 2     Unknown    NaN          1.0

# %%
terror.sum()

# %%
region_list = ['Central America & Caribbean', 'Middle East & North Africa', 
               'North America', 'South America', 'South Asia', 'Southeast Asia', 'Sub-Saharan Africa', 'Western Europe']
target_list = terror.groupby('Target_type').size().index.tolist()

print(region_list)
print(target_list)

#  Australasia & Oceania, Central Asia, East Asia
# Out:
# ['Central America & Caribbean', 'Middle East & North Africa', 'North America', 'South America', 'South Asia', 'Southeast Asia', 'Sub-Saharan Africa', 'Western Europe']
# ['Abortion Related', 'Airports & Aircraft', 'Business', 'Educational Institution', 'Food or Water Supply', 'Government (Diplomatic)', 'Government (General)', 'Journalists & Media', 'Maritime', 'Military', 'NGO', 'Other', 'Police', 'Private Citizens & Property', 'Religious Figures/Institutions', 'Telecommunication', 'Terrorists/Non-State Militia', 'Tourists', 'Transportation', 'Unknown', 'Utilities', 'Violent Political Party']

# %%
region_target_dict = terror.groupby(['Region', 'Target_type']).size().to_dict()
print(region_target_dict)
# Out:
# {('Australasia & Oceania', 'Airports & Aircraft'): 7, ('Australasia & Oceania', 'Business'): 65, ('Australasia & Oceania', 'Educational Institution'): 8, ('Australasia & Oceania', 'Food or Water Supply'): 1, ('Australasia & Oceania', 'Government (Diplomatic)'): 30, ('Australasia & Oceania', 'Government (General)'): 52, ('Australasia & Oceania', 'Journalists & Media'): 4, ('Australasia & Oceania', 'Maritime'): 2, ('Australasia & Oceania', 'Military'): 15, ('Australasia & Oceania', 'NGO'): 1, ('Australasia & Oceania', 'Police'): 32, ('Australasia & Oceania', 'Private Citizens & Property'): 38, ('Australasia & Oceania', 'Religious Figures/Institutions'): 29, ('Australasia & Oceania', 'Telecommunication'): 1, ('Australasia & Oceania', 'Tourists'): 1, ('Australasia & Oceania', 'Transportation'): 10, ('Australasia & Oceania', 'Unknown'): 1, ('Australasia & Oceania', 'Utilities'): 4, ('Australasia & Oceania', 'Violent Political Party'): 3, ('Central America & Caribbean', 'Airports & Aircraft'): 74, ('Central America & Caribbean', 'Business'): 1193, ('Central America & Caribbean', 'Educational Institution'): 205, ('Central America & Caribbean', 'Food or Water Supply'): 17, ('Central America & Caribbean', 'Government (Diplomatic)'): 220, ('Central America & Caribbean', 'Government (General)'): 1114, ('Central America & Caribbean', 'Journalists & Media'): 274, ('Central America & Caribbean', 'Maritime'): 39, ('Central America & Caribbean', 'Military'): 3065, ('Central America & Caribbean', 'NGO'): 26, ('Central America & Caribbean', 'Other'): 3, ('Central America & Caribbean', 'Police'): 590, ('Central America & Caribbean', 'Private Citizens & Property'): 1503, ('Central America & Caribbean', 'Religious Figures/Institutions'): 86, ('Central America & Caribbean', 'Telecommunication'): 150, ('Central America & Caribbean', 'Terrorists/Non-State Militia'): 35, ('Central America & Caribbean', 'Tourists'): 17, ('Central America & Caribbean', 'Transportation'): 406, ('Central America & Caribbean', 'Unknown'): 84, ('Central America & Caribbean', 'Utilities'): 1227, ('Central America & Caribbean', 'Violent Political Party'): 31, ('Central Asia', 'Airports & Aircraft'): 5, ('Central Asia', 'Business'): 35, ('Central Asia', 'Educational Institution'): 7, ('Central Asia', 'Food or Water Supply'): 2, ('Central Asia', 'Government (Diplomatic)'): 33, ('Central Asia', 'Government (General)'): 128, ('Central Asia', 'Journalists & Media'): 21, ('Central Asia', 'Maritime'): 1, ('Central Asia', 'Military'): 91, ('Central Asia', 'NGO'): 10, ('Central Asia', 'Police'): 79, ('Central Asia', 'Private Citizens & Property'): 80, ('Central Asia', 'Religious Figures/Institutions'): 9, ('Central Asia', 'Telecommunication'): 5, ('Central Asia', 'Terrorists/Non-State Militia'): 9, ('Central Asia', 'Tourists'): 2, ('Central Asia', 'Transportation'): 35, ('Central Asia', 'Unknown'): 10, ('Central Asia', 'Utilities'): 9, ('East Asia', 'Airports & Aircraft'): 59, ('East Asia', 'Business'): 102, ('East Asia', 'Educational Institution'): 14, ('East Asia', 'Food or Water Supply'): 1, ('East Asia', 'Government (Diplomatic)'): 35, ('East Asia', 'Government (General)'): 129, ('East Asia', 'Journalists & Media'): 18, ('East Asia', 'Maritime'): 4, ('East Asia', 'Military'): 41, ('East Asia', 'NGO'): 2, ('East Asia', 'Police'): 98, ('East Asia', 'Private Citizens & Property'): 100, ('East Asia', 'Religious Figures/Institutions'): 32, ('East Asia', 'Telecommunication'): 5, ('East Asia', 'Terrorists/Non-State Militia'): 5, ('East Asia', 'Tourists'): 3, ('East Asia', 'Transportation'): 148, ('East Asia', 'Unknown'): 5, ('East Asia', 'Utilities'): 5, ('East Asia', 'Violent Political Party'): 2, ('Eastern Europe', 'Airports & Aircraft'): 31, ('Eastern Europe', 'Business'): 437, ('Eastern Europe', 'Educational Institution'): 60, ('Eastern Europe', 'Food or Water Supply'): 10, ('Eastern Europe', 'Government (Diplomatic)'): 138, ('Eastern Europe', 'Government (General)'): 704, ('Eastern  ...

# %%
size = [0] * len(target_list)
ind = list(range(len(target_list)))
target_index = {key: value for key, value in zip(target_list, ind)}


for r in region_list:
    labels = target_list
    

    
    for t in target_list:
        val = region_target_dict.get((r,t), None)
        if val:
            count = size[target_index[t]]
            count += val
            size.pop(target_index[t])
            size.insert(target_index[t], val)


    fig1, ax1 = plt.subplots()

    cs=cm.Set1(np.arange(40)/40.)
    ax1.pie(size, labels=labels,autopct='%1.1f%%', startangle=90)
    ax1.set_title(str(r))
    plt.tight_layout()
    plt.savefig("region_target/"+ str(r) +'.png')
    plt.show()

# %%
import imageio
import os
print(os.getcwd())
pieanimation = os.getcwd() + "/pieanimation"

files = []

for filename in os.listdir(pieanimation):
    filename = pieanimation + "/" + filename
    files.append(filename)

files.sort()

images = []
for f in files:
    print(f)
    images.append(imageio.imread(f))

imageio.mimsave('movie.gif', images, duration=0.4)
# Out:
# /Users/yeeeeehan/Desktop/CZ 4032/Project
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1970.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1971.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1972.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1973.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1974.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1975.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1976.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1977.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1978.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1979.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1980.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1981.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1982.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1983.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1984.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1985.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1986.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1987.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1988.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1989.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1990.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1991.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1992.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1994.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1995.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1996.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1997.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1998.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/1999.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/2000.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/2001.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/2002.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/2003.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/2004.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/2005.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/2006.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/2007.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/2008.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/2009.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/2010.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/2011.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/2012.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/2013.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/2014.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/2015.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/2016.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/2017.png
# /Users/yeeeeehan/Desktop/CZ 4032/Project/pieanimation/2018.png

# %%
# ffmpeg -f image2 -r 5 -pattern_type glob -i '*.png' -vcodec mpeg4 -y 5.mp4
# Out:
# 32512

# %%
for i in range(3):
    # Pie chart, where the slices will be ordered and plotted counter-clockwise:
    labels = 'Frogs', 'Hogs', 'Dogs', 'Log'
    sizes = [11,4, 5 ,6]
    explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

    fig1, ax1 = plt.subplots()

    ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
            shadow=True, startangle=90)
    ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

    plt.savefig(str(i) +'.png')
    plt.show()
